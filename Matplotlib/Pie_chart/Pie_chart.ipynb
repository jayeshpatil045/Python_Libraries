# %% [markdown]
# '''
#
# @Author: Jayesh Patil
#
# @Date: 2024-09-04
#
# @Last Modified by: Jayesh Patil
#
# @Title: Pie Chart Problems
#
# '''

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# 1.Python programming to create a pie chart of the popularity of programming Languages.

# %%
def popularity_of_language(languages,popularity):
    """
        Description:
            Creates a pie chart showing the popularity of different programming languages.

        Parameters:
            languages (list of str): List of programming languages.
            popularity (list of float): Corresponding popularity percentages of the languages.

        Returns:
            None
    """     
    plt.pie(popularity,labels=languages)
    plt.show()
def main():
    languages= ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
    popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
    popularity_of_language(languages,popularity)

if __name__ == "__main__":
    main()

# %% [markdown]
# 2.Python programming to create a pie chart with a title of the popularity of programming Languages.

# %%
def popularity_of_language(languages,popularity):
    """
        Description:
            Creates a pie chart showing the popularity of different programming languages.

        Parameters:
            languages (list of str): List of programming languages.
            popularity (list of float): Corresponding popularity percentages of the languages.

        Returns:
            None
    """    
    plt.pie(popularity,labels=languages)
    plt.title('popularity of programming Languages')
    plt.show()
def main():
    languages= ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
    popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
    popularity_of_language(languages,popularity)

if __name__ == "__main__":
    main()

# %% [markdown]
# 3.Python programming to create a pie chart of gold medal achievements of five most successful countries in 2016 Summer Olympics. Read the data from a csv file.

# %%
def read_medal_data(filename):
    """
        Description:
            Reads gold medal data from a CSV file.

        Parameters:
            filename (str): The path to the CSV file containing the medal data.

        Returns:
            countries (list of str): List of country names.
            gold_medals (list of int): Corresponding list of gold medals won by each country.
    """
    countries = []
    gold_medals = []

    with open(filename, 'r') as medals:
        reader = csv.reader(medals)
        next(reader)  
        for row in reader:
            countries.append(row[0])
            gold_medals.append(int(row[1]))

    return countries, gold_medals

def plot_medal_pie_chart(countries, gold_medals):
    
    plt.figure(figsize=(8, 8))
    plt.pie(gold_medals, labels=countries, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
    
    plt.title('Gold Medal Achievements in 2016 Summer Olympics')
    
    plt.axis('equal')
    
    plt.show()

def main():
    filename = 'medal.csv'
    countries, gold_medals = read_medal_data(filename)

    plot_medal_pie_chart(countries, gold_medals)

if __name__ == "__main__":
    main()
